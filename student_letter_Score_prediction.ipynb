# %% [markdown]
# <a href="https://colab.research.google.com/github/ercefd/studentLetterScorePrediction/blob/main/student_letter_Score_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('grades.csv')
df.head(3)
# Out:
#    Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade
# 0    2.5       0.5       0.0        2        2.3      21     C
# 1    5.1       1.5       0.5        4        4.9      47     B
# 2    3.2       1.0       0.5        3        2.9      27     C

# %%
# !pip install keras
from keras.models import Sequential
from keras.layers import Dense

# %%
y=df['Scores']
x=df.drop(columns=["Scores", "Grade"])

y=y.values.astype('float32')
x=x.values.astype('float32')

# %%
model=Sequential()
model.add(Dense(16))
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(x,y, epochs=90, batch_size=16)
# Out:
# Epoch 1/90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 3063.6865
# Epoch 2/90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3121.6455
# Epoch 3/90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2978.9827
# Epoch 4/90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3078.7759
# Epoch 5/90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2731.7214
# Epoch 6/90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2852.4895
# Epoch 7/90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2822.3215
# Epoch 8/90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2681.0334
# Epoch 9/90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2548.2646
# Epoch 10/90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2717.1033
# Epoch 11/90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2399.8308
# Epoch 12/90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2365.7434
# Epoch 13/90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2366.6807
# Epoch 14/90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2185.9209
# ...

# %%
df.head(3)
# Out:
#    Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade
# 0    2.5       0.5       0.0        2        2.3      21     C
# 1    5.1       1.5       0.5        4        4.9      47     B
# 2    3.2       1.0       0.5        3        2.9      27     C

# %%
model.predict(np.array([[23,1,1,2,3.3]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# array([[78.75468]], dtype=float32)
